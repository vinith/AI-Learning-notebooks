# %%
import idx2numpy
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import random as rand
np.set_printoptions(suppress=True)

x_digit = idx2numpy.convert_from_file('data/train-images-idx3-ubyte')
y_digit = idx2numpy.convert_from_file('data/train-labels-idx1-ubyte')

print(x_digit.shape, y_digit.shape)
BATCH_SIZE = 1024
TRAIN_SIZE = 50000
TEST_SIZE = 10000
# Out:
# (60000, 28, 28) (60000,)

# %%
### Generate train and test data using mnist set with NUM_SIZE digits
GRID_SIDE = 9

image_dict = [[] for i in range(10)]
for digit,image in zip(y_digit, x_digit):
    image_dict[digit].append(image)

# %%
class TestImgGenSequence(keras.utils.Sequence):
    
    def __init__(self, length_of_set, batch_size=BATCH_SIZE):
        self.batch_size = batch_size
        self.length_of_set = length_of_set
    
    def __len__(self):
        'Denotes the number of batches per epoch 10k/128'
        ret = self.length_of_set // self.batch_size
        #print("Returning length as " + str(ret))
        return ret

    def __getitem__(self, index):
        'Generate one batch of data'
        #print("Getting item for index " + str(index))
        # Generate indexes of the batch
        #print("using batch_size " + str(self.batch_size))
        x, y = self.gen_test_data(self.batch_size)
        x /= 255.0
        y = tf.one_hot(y, 10).numpy()
        #print("Shapes of returned ", x.shape, y.shape)
        ys = {}
        for op_l in range(GRID_SIDE**2):
            ys[op_l] = y[:,op_l,:]
        return x,ys
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        #print("An epoch ended >>>>>>> xxxxxxx >>>>>> qqq >>>>")
        
    def gen_test_data(self,num_data):
        x_data, y_data = np.zeros((num_data, GRID_SIDE * 28 , GRID_SIDE * 28)), np.zeros((num_data, GRID_SIDE **2))
        for i in range(num_data):
            for k in range(GRID_SIDE**2):
                rand_digit = rand.randint(0,9)
                rand_img = rand.choice(image_dict[rand_digit])
                y_data[i,k] = rand_digit
                r = k//GRID_SIDE
                c = k % GRID_SIDE
                x_data[i,r*28:(r+1)*28,28*c:28*(c+1)] = rand_img
        return x_data, y_data

# %%
act = None
pad = 'same'
strd = 1
input_layer = tf.keras.Input(shape = (GRID_SIDE*28, GRID_SIDE*28,1))
_ = tf.keras.layers.Conv2D(filters=3, kernel_size=3, activation = act, padding = pad, strides=2)(input_layer)
_ = tf.keras.layers.Conv2D(filters=3*2, kernel_size=3, activation = act, padding = pad, strides=strd)(_) 
_ = tf.keras.layers.MaxPool2D()(_)
_ = tf.keras.layers.Conv2D(filters=3*3, kernel_size=3, activation = act, padding = pad, strides = strd)(_) 
_ = tf.keras.layers.Conv2D(filters=3*4, kernel_size=3, activation = act, padding = pad, strides = strd)(_)
_ = tf.keras.layers.MaxPool2D()(_)
#_ = tf.keras.layers.Conv3D(filters=500, kernel_size=(1,1,8), activation = act, padding = pad, strides = strd)(_)
#common_layer = tf.keras.layers.Conv2D(filters=100, kernel_size=1, activation = act, padding = pad, strides = strd)(_) 
_ = tf.keras.layers.Reshape((31*31,12))(_)
#_ = tf.keras.layers.Flatten()(_)
#_ = tf.keras.layers.Dense(1000, activation = act)(_)
#_ = tf.keras.layers.Dense(100, activation = act)(_)
common_layer = tf.keras.layers.Conv1D(1, kernel_size=1, activation = act)(_)
common_layer = tf.keras.layers.Flatten()(common_layer)
common_layer = tf.keras.layers.Dense(800, activation = act)(common_layer)
common_layer = tf.keras.layers.Dense(200, activation = act)(common_layer)
#common_layer = tf.keras.layers.Dropout(rate=0.1)(_)

#One output layer per digit
output_layers = {}
output_loss_fns = {}
output_metrics = {}
for op_l in range(GRID_SIDE ** 2):
    layer_name = "output_digit_" + str(op_l)
    #output_layers[op_l] = tf.keras.layers.Conv2D(filters = 10, kernel_size = 1, activation = 'softmax', name=layer_name)(common_layer)
    output_layers[op_l] = tf.keras.layers.Dense(10, activation = 'softmax', name=layer_name)(common_layer)
    output_loss_fns[op_l] = tf.keras.losses.CategoricalCrossentropy()
    output_metrics[op_l] = 'accuracy'

model = tf.keras.Model(inputs=input_layer, outputs = output_layers, name="digit_recognizer")
model.compile(optimizer=tf.keras.optimizers.Adamax(),
             loss = output_loss_fns,
             metrics = ['accuracy'] )

model.summary()
# Out:
# Model: "digit_recognizer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 252, 252, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 126, 126, 3)  30          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 126, 126, 6)  168         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 63, 63, 6)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 63, 63, 9)    495         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 63, 63, 12)   984         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 31, 31, 12)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 961, 12)      0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 961, 1)       13          reshape[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 961)          0           conv1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 800)          769600      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          160200      dense[0][0]
# __________________________________________________________________________________________________
# output_digit_0 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_1 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_2 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_3 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_4 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_5 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_6 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_7 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_8 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_9 (Dense)          (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_10 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_11 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_12 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_13 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_14 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_15 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_16 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_17 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_18 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_19 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_20 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_21 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_22 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_23 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_24 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_25 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_26 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_27 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_28 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_29 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_30 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_31 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_32 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_33 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_34 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_35 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_36 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_37 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_38 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_39 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_40 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_41 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_42 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_43 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_44 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_45 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_46 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_47 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_48 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_49 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_50 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_51 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_52 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_53 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_54 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_55 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_56 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_57 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_58 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_59 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_60 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_61 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_62 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_63 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_64 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_65 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_66 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_67 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_68 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_69 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_70 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_71 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_72 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_73 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_74 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_75 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_76 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_77 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_78 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_79 (Dense)         (None, 10)           2010        dense_1[0][0]
# __________________________________________________________________________________________________
# output_digit_80 (Dense)         (None, 10)           2010        dense_1[0][0]
# ==================================================================================================
# Total params: 1,094,300
# Trainable params: 1,094,300
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
training_gen = TestImgGenSequence(TRAIN_SIZE)
validation_gen = TestImgGenSequence(TEST_SIZE)

model.fit(x = training_gen, epochs=100, batch_size=BATCH_SIZE, verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     886         # Lifting succeeded, so variables are initialized and we can run the
#     887         # stateless function.
# --> 888         return self._stateless_fn(*args, **kwds)
#     889     else:
#     890       _, _, _, filtered_flat_args = \
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2939     with self._lock:
#    2940       (graph_function,
# -> 2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     964           # TODO(mdan): Push this block higher in tf.function's call stack.
#     965           try:
# --> 966             return autograph.converted_call(
#     967                 original_func,
#     968                 args,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     457     try:
#     458       if kwargs is not None:
# --> 459         result = converted_f(*effective_args, **kwargs)
#     460       else:
#     461         result = converted_f(*effective_args)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in tf__train_function(iterator)
#      14                 try:
#      15                     do_return = True
# ---> 16                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      17                 except:
#      18                     do_return = False
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     348   if conversion.is_in_allowlist_cache(f, options):
#     349     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 350     return _call_unconverted(f, args, kwargs, options, False)
#     351
#     352   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     477   if kwargs is not None:
#     478     return f(*args, **kwargs)
# --> 479   return f(*args)
#     480
#     481
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in step_function(model, iterator)
#     793
#     794       data = next(iterator)
# --> 795       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     796       outputs = reduce_per_replica(
#     797           outputs, self.distribute_strategy, reduction='first')
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1257       fn = autograph.tf_convert(
#    1258           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1259       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1260
#    1261   def reduce(self, reduce_op, value, axis):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2728       kwargs = {}
#    2729     with self._container_strategy().scope():
# -> 2730       return self._call_for_each_replica(fn, args, kwargs)
#    2731
#    2732   def _call_for_each_replica(self, fn, args, kwargs):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3415   def _call_for_each_replica(self, fn, args, kwargs):
#    3416     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3417       return fn(*args, **kwargs)
#    3418
#    3419   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     665       try:
#     666         with conversion_ctx:
# --> 667           return converted_call(f, args, kwargs, options=options)
#     668       except Exception as e:  # pylint:disable=broad-except
#     669         if hasattr(e, 'ag_error_metadata'):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     394
#     395   if not options.user_requested and conversion.is_allowlisted(f):
# --> 396     return _call_unconverted(f, args, kwargs, options)
#     397
#     398   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     476
#     477   if kwargs is not None:
# --> 478     return f(*args, **kwargs)
#     479   return f(*args)
#     480
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in run_step(data)
#     786
#     787       def run_step(data):
# --> 788         outputs = model.train_step(data)
#     789         # Ensure counter is updated only if `train_step` succeeds.
#     790         with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in train_step(self, data)
#     753     with backprop.GradientTape() as tape:
#     754       y_pred = self(x, training=True)
# --> 755       loss = self.compiled_loss(
#     756           y, y_pred, sample_weight, regularization_losses=self.losses)
#     757     self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py in __call__(self, y_true, y_pred, sample_weight, regularization_losses)
#     201       y_t, y_p, sw = match_dtype_and_rank(y_t, y_p, sw)
#     202       sw = apply_mask(y_p, sw, get_mask(y_p))
# --> 203       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     204
#     205       loss_metric_value = loss_value
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     155       else:
#     156         call_fn = autograph.tf_convert(self.call, ag_ctx.control_status_ctx())
# --> 157       losses = call_fn(y_true, y_pred)
#     158       return losses_utils.compute_weighted_loss(
#     159           losses, sample_weight, reduction=self._get_reduction())
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     665       try:
#     666         with conversion_ctx:
# --> 667           return converted_call(f, args, kwargs, options=options)
#     668       except Exception as e:  # pylint:disable=broad-except
#     669         if hasattr(e, 'ag_error_metadata'):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     348   if conversion.is_in_allowlist_cache(f, options):
#     349     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 350     return _call_unconverted(f, args, kwargs, options, False)
#     351
#     352   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     476
#     477   if kwargs is not None:
# --> 478     return f(*args, **kwargs)
#     479   return f(*args)
#     480
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/losses.py in call(self, y_true, y_pred)
#     259           y_pred, y_true)
#     260     ag_fn = autograph.tf_convert(self.fn, ag_ctx.control_status_ctx())
# --> 261     return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     262
#     263   def get_config(self):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/losses.py in categorical_crossentropy(y_true, y_pred, from_logits, label_smoothing)
#    1560   y_true = smart_cond.smart_cond(label_smoothing, _smooth_labels,
#    1561                                  lambda: y_true)
# -> 1562   return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#    1563
#    1564
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in categorical_crossentropy(target, output, from_logits, axis)
#    4876
#    4877   if from_logits:
# -> 4878     return nn.softmax_cross_entropy_with_logits_v2(
#    4879         labels=target, logits=output, axis=axis)
#    4880
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2(labels, logits, axis, name)
#    3925     not have the last dimension of `labels`.
#    3926   """
# -> 3927   return softmax_cross_entropy_with_logits_v2_helper(
#    3928       labels=labels, logits=logits, axis=axis, name=name)
#    3929
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     536                 'in a future version' if date is None else ('after %s' % date),
#     537                 instructions)
# --> 538       return func(*args, **kwargs)
#     539
#     540     doc = _add_deprecated_arg_notice_to_docstring(
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2_helper(***failed resolving arguments***)
#    4022     # Make precise_logits and labels into matrices.
#    4023     precise_logits = _flatten_outer_dims(precise_logits)
# -> 4024     labels = _flatten_outer_dims(labels)
#    4025
#    4026     # Do the actual op computation.
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py in _flatten_outer_dims(logits)
#    3615   """Flattens logits' outer dimensions and keep its last dimension."""
#    3616   rank = array_ops.rank(logits)
# -> 3617   last_dim_size = array_ops.slice(
#    3618       array_ops.shape(logits), [math_ops.subtract(rank, 1)], [1])
#    3619   output = array_ops.reshape(logits, array_ops.concat([[-1], last_dim_size], 0))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py in slice(input_, begin, size, name)
#    1101     A `Tensor` the same type as `input_`.
#    1102   """
# -> 1103   return gen_array_ops._slice(input_, begin, size, name=name)
#    1104
#    1105
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py in _slice(input, begin, size, name)
#    9388       pass  # Add nodes to the TensorFlow graph.
#    9389   # Add nodes to the TensorFlow graph.
# -> 9390   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9391         "Slice", input=input, begin=begin, size=size, name=name)
#    9392   _result = _outputs[:]
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     515                   preferred_dtype=default_dtype)
#     516           else:
# --> 517             values = ops.convert_to_tensor(
#     518                 values,
#     519                 name=input_arg.name,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279   tensor_value = attr_value_pb2.AttrValue()
#     280   tensor_value.tensor.CopyFrom(
# --> 281       tensor_util.make_tensor_proto(
#     282           value, dtype=dtype, shape=shape, verify_shape=verify_shape,
#     283           allow_broadcast=allow_broadcast))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape, allow_broadcast)
#     562     raise TypeError(
#     563         "Element type not supported in TensorProto: %s" % numpy_dtype.name)
# --> 564   append_fn(tensor_proto, proto_values)
#     565
#     566   return tensor_proto
#
# tensorflow/python/framework/fast_tensor_util.pyx in tensorflow.python.framework.fast_tensor_util.AppendInt32ArrayToTensorProto()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/p38TF/lib/python3.8/site-packages/google/protobuf/internal/python_message.py in getter(self)
#     654
#     655   def getter(self):
# --> 656     field_value = self._fields.get(field)
#     657     if field_value is None:
#     658       # Construct a new object to represent this field.
#
# KeyboardInterrupt:

# %%
model.evaluate(x=validation_gen, y=None)
# Out:
# 9/9 [==============================] - 10s 417ms/step - loss: 189.6205 - output_digit_0_loss: 2.3367 - output_digit_1_loss: 2.3256 - output_digit_2_loss: 2.3339 - output_digit_3_loss: 2.3449 - output_digit_4_loss: 2.3517 - output_digit_5_loss: 2.3290 - output_digit_6_loss: 2.3582 - output_digit_7_loss: 2.3353 - output_digit_8_loss: 2.3484 - output_digit_9_loss: 2.3335 - output_digit_10_loss: 2.3351 - output_digit_11_loss: 2.3514 - output_digit_12_loss: 2.3648 - output_digit_13_loss: 2.3538 - output_digit_14_loss: 2.3488 - output_digit_15_loss: 2.3591 - output_digit_16_loss: 2.3380 - output_digit_17_loss: 2.3590 - output_digit_18_loss: 2.3246 - output_digit_19_loss: 2.3255 - output_digit_20_loss: 2.3401 - output_digit_21_loss: 2.3402 - output_digit_22_loss: 2.3408 - output_digit_23_loss: 2.3192 - output_digit_24_loss: 2.3644 - output_digit_25_loss: 2.3349 - output_digit_26_loss: 2.3474 - output_digit_27_loss: 2.3263 - output_digit_28_loss: 2.3383 - output_digit_29_loss: 2.3493 - output_digit_30_loss: 2.3211 - output_digit_31_loss: 2.3398 - output_digit_32_loss: 2.3350 - output_digit_33_loss: 2.3514 - output_digit_34_loss: 2.3410 - output_digit_35_loss: 2.3481 - output_digit_36_loss: 2.3451 - output_digit_37_loss: 2.3719 - output_digit_38_loss: 2.3495 - output_digit_39_loss: 2.3373 - output_digit_40_loss: 2.3711 - output_digit_41_loss: 2.3595 - output_digit_42_loss: 2.3424 - output_digit_43_loss: 2.3446 - output_digit_44_loss: 2.3321 - output_digit_45_loss: 2.3307 - output_digit_46_loss: 2.3425 - output_digit_47_loss: 2.3464 - output_digit